# %% [markdown]
# # Data Science Task

# %% [markdown]
# ## Import the relevant libraries

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('drinkMenu.csv')
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
# Show data types to know how to deal with data 
df.dtypes
# Out:
# Beverage_category             object
# Beverage                      object
# Beverage_prep                 object
# Calories                       int64
#  Total Fat (g)                object
# Trans Fat (g)                float64
# Saturated Fat (g)            float64
#  Sodium (mg)                   int64
#  Total Carbohydrates (g)       int64
# Cholesterol (mg)               int64
#  Dietary Fibre (g)             int64
#  Sugars (g)                    int64
#  Protein (g)                 float64
# Vitamin A (% DV)              object
# Vitamin C (% DV)              object
#  Calcium (% DV)               object
# Iron (% DV)                   object
# Caffeine (mg)                 object
# dtype: object

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### 1.Remove duplicates

# %%
# df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
# preview dataframe and we figure out that there is no duplicate data
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %% [markdown]
# ### 2.Fill null values

# %%
# first know there are null values or no
# then choose how to deal with it 
df.isnull().sum()
# Out:
# Beverage_category            0
# Beverage                     0
# Beverage_prep                0
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                1
# dtype: int64

# %%
# we know that one NaN value found in Caffeine (mg)  columns
# so show row which has null values 
df[df.isnull().any(axis=1)]
# Out:
#          Beverage_category                                        Beverage  \
# 158  Shaken Iced Beverages  Iced Brewed Coffee (With Milk & Classic Syrup)
#
#     Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# 158       2% Milk        90              1             0.5                0.0
#
#       Sodium (mg)   Total Carbohydrates (g)   Cholesterol (mg)  \
# 158             5                         25                18
#
#       Dietary Fibre (g)   Sugars (g)   Protein (g)  Vitamin A (% DV)   \
# 158                   0           18            2.0                2%
#
#     Vitamin C (% DV)  Calcium (% DV)  Iron (% DV)  Caffeine (mg)
# 158               0%               6%        0.00%           NaN

# %%
# at First there are many ways to deal with null values 
# 1.Drop null values 
# 2.ask stakeholders for values: 
# and when search for Iced Brewed Coffee (With Milk & Classic Syrup) Beverage 
# with 2%milk Beverage_prep we find Caffeine (mg) = 125 
# if we Choose to work caffeine (mg) =125
df_clean = df.fillna(125)
df_clean.loc[[158]]
# Out:
#          Beverage_category                                        Beverage  \
# 158  Shaken Iced Beverages  Iced Brewed Coffee (With Milk & Classic Syrup)
#
#     Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# 158       2% Milk        90              1             0.5                0.0
#
#       Sodium (mg)   Total Carbohydrates (g)   Cholesterol (mg)  \
# 158             5                         25                18
#
#       Dietary Fibre (g)   Sugars (g)   Protein (g)  Vitamin A (% DV)   \
# 158                   0           18            2.0                2%
#
#     Vitamin C (% DV)  Calcium (% DV)  Iron (% DV)  Caffeine (mg)
# 158               0%               6%        0.00%           125

# %% [markdown]
# ### 3.Drop unnecessary Columns

# %% [markdown]
# ##### we can drop Vitamin A (% DV), Vitamin C (% DV), Calcium (% DV), Iron (% DV)  and other columns that we don't need it in our analysis now

# %%
dfcopy = df_clean.copy()
dfcopy.drop(['Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',' Total Carbohydrates (g) ', ' Dietary Fibre (g)', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
       'Iron (% DV) ',' Calcium (% DV) ', 'Caffeine (mg)'], axis=1, inplace=True)
dfcopy.head()
# Out:
#          Beverage_category       Beverage      Beverage_prep  Calories  \
# 0                   Coffee  Brewed Coffee              Short         3
# 1                   Coffee  Brewed Coffee               Tall         4
# 2                   Coffee  Brewed Coffee             Grande         5
# 3                   Coffee  Brewed Coffee              Venti         5
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
#
#    Total Fat (g)  Cholesterol (mg)   Sugars (g)   Protein (g)
# 0            0.1                 0            0            0.3
# 1            0.1                 0            0            0.5
# 2            0.1                 0            0            1.0
# 3            0.1                 0            0            1.0
# 4            0.1                10            9            6.0

# %% [markdown]
# ## Data Visualisations

# %% [markdown]
# ### Q1.Which drink has the highest calories from the dataset?

# %%
# sort data and show highest value of Calories
dfcopy.sort_values("Calories", ascending=False).head(2)
# Out:
#                Beverage_category  \
# 84     Signature Espresso Drinks
# 215  Frappuccino® Blended Coffee
#
#                                           Beverage Beverage_prep  Calories  \
# 84   White Chocolate Mocha (Without Whipped Cream)       2% Milk       510
# 215              Java Chip (Without Whipped Cream)    Whole Milk       460
#
#      Total Fat (g)  Cholesterol (mg)   Sugars (g)   Protein (g)
# 84              15                77           74           19.0
# 215             10                90           84            7.0

# %%
# data visualization to see the which drink has the highest calories
plt.figure(figsize=(25, 10))
plt.title('Drink Beverage Calories')
plt.xticks(rotation=45, ha='right')
plt.bar(dfcopy['Beverage'], dfcopy['Calories'])
plt.ylim(0 , 550)
# sns.barplot(x="Beverage", y="Calories", data=df_clean)
plt.show()

# %% [markdown]
# #### From previous the graph, we see White Chocolate Mocha (Without Whipped Cream) has the highest calories in the dataset

# %% [markdown]
# ### 2.Highest Sugar Drink

# %%
# sort data and show highest value of Calories
dfcopy.sort_values(" Sugars (g)", ascending=False).head(2)
# Out:
#                Beverage_category                           Beverage  \
# 214  Frappuccino® Blended Coffee  Java Chip (Without Whipped Cream)
# 215  Frappuccino® Blended Coffee  Java Chip (Without Whipped Cream)
#
#          Beverage_prep  Calories  Total Fat (g)  Cholesterol (mg)  \
# 214  Venti Nonfat Milk       420              5                90
# 215         Whole Milk       460             10                90
#
#       Sugars (g)   Protein (g)
# 214           84            7.0
# 215           84            7.0

# %%
# data visualization to see the which drink has the highest calories
plt.figure(figsize=(25, 10))
plt.title('Drink Beverage  Sugars (g)')
plt.xticks(rotation=45, ha='right')
# plt.xlim(0 , 50)
plt.ylim(0 , 450)
# plt.bar(df_clean['Beverage'], df_clean[' Sugars (g)'])
sns.barplot(x="Beverage", y="Calories", data=dfcopy)
plt.show()

# %% [markdown]
# #### From the previous graph, we see Java Chip (Without Whipped Cream) (Venti Nonfat Milk and Whole Milk) has the highest Sugar in the dataset
